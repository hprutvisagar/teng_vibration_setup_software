# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack

# Number of samplepoints
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.show()

# %%
time=[11460,11569,11677,11786,11894,12002,12111,12219,12328,12436,
 12543,12652,12761,12870,12978,13086,13195,13302,13411,13520,
 13627,13736,13845,13954,14061,14170,14278,14387,14495,14603,
 14712,14820,14928,15038,15146,15253,15362,15471,15580,15688,
 15795,15905,16013,16122,16230,16338,16447]
G_values =[11.09,9.24,12.23,11.76,8.3, 9.13,8.99,9.3, 9.9,10.71,
  14.77,8.33,9.56,9.67,9.11,9.8,12.11,10.62,8,10.69,
  10.79,9.1,-13.79,16.35,6.39,10.37,8.81,10.42,10.19,9.65,
  10.08,10.12,9.98,9.93,10.13,10.01,9.92,9.95,9.9,10.06, 9.87,9.93,9.92,9.95,10.07,9.91,9.88]

# %%
plt.plot(time,G_values)

# %%
# Number of samplepoints
N = len(time)
# sample spacing
T = 1.0 / N
# x = np.linspace(0.0, N*T, N)
# y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = scipy.fftpack.fft(G_values)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.show()

# %%
yf
# Out:
# array([451.2        -0.j        ,  22.49264281 +2.02439287j,
#        -19.54429883 -8.04102308j,  19.49959795+12.67988696j,
#         -9.70596245-12.61742095j,  17.85775255+14.24890634j,
#         -2.01353082-28.76668251j,  -6.75395012+10.38650746j,
#         -4.12323895-14.6610757j ,  -6.02518896+20.74325694j,
#         12.38297698-20.11260902j, -21.7627977 +13.79024377j,
#         19.16398613 -9.33347408j, -31.4555597 +12.38183454j,
#         32.01554093+10.56594501j, -16.57495909 -8.51103575j,
#         19.17600954 +9.91525895j, -19.20910627 -8.98755022j,
#         24.72425954+24.24336037j,  -7.94006899-23.31329478j,
#         18.41451616+21.68084629j, -14.64073768-34.3795799j ,
#          6.07742083+37.65421322j,   2.95969615-31.91930497j,
#          2.95969615+31.91930497j,   6.07742083-37.65421322j,
#        -14.64073768+34.3795799j ,  18.41451616-21.68084629j,
#         -7.94006899+23.31329478j,  24.72425954-24.24336037j,
# ...
